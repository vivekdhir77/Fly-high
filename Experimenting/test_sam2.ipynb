# %%
from collections import defaultdict

import cv2
import numpy as np

from ultralytics import YOLO

model = YOLO("yolov8n.pt")
video_path = "/Users/sansh/Documents/visual_ai/Fly-high-main/4457089-hd_1920_1080_30fps.mp4"
cap = cv2.VideoCapture(video_path)
track_history = defaultdict(lambda: [])

# %%
import cv2
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

cap = cv2.VideoCapture("/Users/sansh/Documents/visual_ai/Fly-high-main/4457089-hd_1920_1080_30fps.mp4") 

while cap.isOpened():
    success, frame = cap.read()

    if success:
        results = model.track(frame, persist=True)

        boxes = results[0].boxes.xywh.cpu()
        scores = results[0].boxes.conf.cpu()

        annotated_frame = results[0].plot()

        if results[0].boxes.id is not None:
            track_ids = results[0].boxes.id.int().cpu().tolist()
            for box, track_id, score in zip(boxes, track_ids, scores):
                x, y, w, h = box
                cv2.putText(annotated_frame, f"ID: {track_id}, Conf: {score:.2f}", 
                            (int(x), int(y) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
        else:
            for box, score in zip(boxes, scores):
                x, y, w, h = box
                cv2.putText(annotated_frame, f"Conf: {score:.2f}", 
                            (int(x), int(y) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

        cv2.imshow("YOLOv8 Tracking", annotated_frame)

        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 52 birds, 1 kite, 35.8ms
# Speed: 2.7ms preprocess, 35.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 54 birds, 1 kite, 37.2ms
# Speed: 1.7ms preprocess, 37.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 48 birds, 1 kite, 36.7ms
# Speed: 1.6ms preprocess, 36.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 51 birds, 1 kite, 29.1ms
# Speed: 1.4ms preprocess, 29.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 43 birds, 26.7ms
# Speed: 1.6ms preprocess, 26.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 48 birds, 28.4ms
# Speed: 1.6ms preprocess, 28.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 birds, 30.4ms
# Speed: 1.3ms preprocess, 30.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 43 birds, 1 kite, 38.6ms
# ...

# %%
while cap.isOpened():
    success, frame = cap.read()
    if success:
        results = model.track(frame, persist=True)
        boxes = results[0].boxes.xywh.cpu()
        track_ids = results[0].boxes.id.int().cpu().tolist()
        annotated_frame = results[0].plot()
        for box, track_id in zip(boxes, track_ids):
            x, y, w, h = box
            track = track_history[track_id]
            track.append((float(x), float(y)))
            if len(track) > 30:
                track.pop(0)
            points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
            cv2.polylines(annotated_frame, [points], isClosed=False, color=(230, 230, 230), thickness=10)
        cv2.imshow("YOLOv8 Tracking", annotated_frame)
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 52 birds, 1 kite, 79.9ms
# Speed: 5.8ms preprocess, 79.9ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 6
#       4 results = model.track(frame, persist=True)
#       5 boxes = results[0].boxes.xywh.cpu()
# ----> 6 track_ids = results[0].boxes.id.int().cpu().tolist()
#       7 annotated_frame = results[0].plot()
#       8 for box, track_id in zip(boxes, track_ids):
#
# AttributeError: 'NoneType' object has no attribute 'int'
